# %%
# !git clone https://github.com/dfeddema/tiny_results_v0.5.git
# Out:
# fatal: destination path 'tiny_results_v0.5' already exists and is not an empty directory.

# %%
! cd ./tiny_results_v0.5/closed/reference/code/training/image_classification/  && ls -l  && pwd && wget https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz  && tar -xvf cifar-10-python.tar.gz
# Out:
# total 333156
# -rw-r--r--. 1 1000980000 1000980000      4128 Oct 11 23:58 calibration_samples_idxs.npy
# -rw-r--r--. 1 1000980000 1000980000     11894 Oct 11 23:58 calibration_samples.txt
# drwxr-sr-x. 2 1000980000 1000980000      4096 Jun  4  2009 cifar-10-batches-py
# -rw-r--r--. 1 1000980000 1000980000 170498071 Jun  4  2009 cifar-10-python.tar.gz
# -rw-r--r--. 1 1000980000 1000980000 170498071 Jun  4  2009 cifar-10-python.tar.gz.1
# -rwxr-xr-x. 1 1000980000 1000980000        81 Oct 11 23:58 convert_to_tflite.sh
# -rw-r--r--. 1 1000980000 1000980000       267 Oct 11 23:58 download_cifar10_train_resnet.sh
# -rw-r--r--. 1 1000980000 1000980000      8694 Oct 11 23:58 eval_functions_eembc.py
# -rw-r--r--. 1 1000980000 1000980000      5900 Oct 11 23:58 keras_model.py
# -rw-r--r--. 1 1000980000 1000980000      1457 Oct 11 23:58 model_converter.py
# drwxr-sr-x. 2 1000980000 1000980000     12288 Oct 11 23:58 perf_samples
# -rw-r--r--. 1 1000980000 1000980000      1728 Oct 11 23:58 perf_samples_idxs.npy
# -rw-r--r--. 1 1000980000 1000980000      1033 Oct 11 23:58 perf_samples_loader.py
# -rwxr-xr-x. 1 1000980000 1000980000        85 Oct 11 23:58 prepare_training_env.sh
# drwxr-sr-x. 2 1000980000 1000980000      4096 Oct 12 00:04 __pycache__
# -rw-r--r--. 1 1000980000 1000980000      1226 Oct 11 23:58 README.md
# -rw-r--r--. 1 1000980000 1000980000       857 Oct 11 23:58 requirements.txt
# -rw-r--r--. 1 1000980000 1000980000      2123 Oct 11 23:58 test.py
# -rw-r--r--. 1 1000980000 1000980000      2717 Oct 11 23:58 tflite_test.py
# drwxr-sr-x. 2 1000980000 1000980000      4096 Oct 12 01:37 trained_models
# -rw-r--r--. 1 1000980000 1000980000     18740 Oct 12 01:37 train_loss_acc.png
# -rw-r--r--. 1 1000980000 1000980000      6189 Oct 12 03:13 train.py
# -rw-r--r--. 1 1000980000 1000980000       616 Oct 12 00:05 Untitled.ipynb
# -rw-r--r--. 1 1000980000 1000980000      5751 Oct 12 00:04 y_labels.csv
# /opt/app-root/src/tiny_results_v0.5/closed/reference/code/training/image_classification
# --2021-10-12 03:13:43--  https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# Resolving www.cs.toronto.edu (www.cs.toronto.edu)... 128.100.3.30
# Connecting to www.cs.toronto.edu (www.cs.toronto.edu)|128.100.3.30|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 170498071 (163M) [application/x-gzip]
# Saving to: ‘cifar-10-python.tar.gz.2’
#
# cifar-10-python.tar 100%[===================>] 162.60M  69.5MB/s    in 2.3s
#
# 2021-10-12 03:13:45 (69.5 MB/s) - ‘cifar-10-python.tar.gz.2’ saved [170498071/170498071]
#
# cifar-10-batches-py/
# cifar-10-batches-py/data_batch_4
# cifar-10-batches-py/readme.html
# cifar-10-batches-py/test_batch
# cifar-10-batches-py/data_batch_3
# cifar-10-batches-py/batches.meta
# cifar-10-batches-py/data_batch_2
# cifar-10-batches-py/data_batch_5
# cifar-10-batches-py/data_batch_1

# %%
# !cd ./tiny_results_v0.5/closed/reference/code/training/image_classification/ && pip install -r requirements.txt  && python perf_samples_loader.py && python train.py
# Out:
# Requirement already satisfied: absl-py==0.11.0 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 1)) (0.11.0)
# Requirement already satisfied: astunparse==1.6.3 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 2)) (1.6.3)
# Requirement already satisfied: cachetools==4.2.1 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 3)) (4.2.1)
# Requirement already satisfied: certifi==2020.12.5 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 4)) (2020.12.5)
# Requirement already satisfied: chardet==4.0.0 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 5)) (4.0.0)
# Requirement already satisfied: cycler==0.10.0 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 6)) (0.10.0)
# Requirement already satisfied: flatbuffers==1.12 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 7)) (1.12)
# Requirement already satisfied: gast==0.3.3 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 8)) (0.3.3)
# Requirement already satisfied: google-auth==1.27.0 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 9)) (1.27.0)
# Requirement already satisfied: google-auth-oauthlib==0.4.2 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 10)) (0.4.2)
# Requirement already satisfied: google-pasta==0.2.0 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 11)) (0.2.0)
# Requirement already satisfied: grpcio==1.32.0 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 12)) (1.32.0)
# Requirement already satisfied: h5py==2.10.0 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 13)) (2.10.0)
# Requirement already satisfied: idna==2.10 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 14)) (2.10)
# Requirement already satisfied: imageio==2.9.0 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 15)) (2.9.0)
# Requirement already satisfied: joblib==1.0.1 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 16)) (1.0.1)
# Requirement already satisfied: Keras==2.4.3 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 17)) (2.4.3)
# Requirement already satisfied: Keras-Preprocessing==1.1.2 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 18)) (1.1.2)
# Requirement already satisfied: kiwisolver==1.3.1 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 19)) (1.3.1)
# Requirement already satisfied: Markdown==3.3.3 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 20)) (3.3.3)
# Requirement already satisfied: matplotlib==3.3.4 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 21)) (3.3.4)
# Requirement already satisfied: numpy==1.19.5 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 22)) (1.19.5)
# Requirement already satisfied: oauthlib==3.1.0 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 23)) (3.1.0)
# Requirement already satisfied: opencv-python==4.5.1.48 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 24)) (4.5.1.48)
# Requirement already satisfied: opt-einsum==3.3.0 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 25)) (3.3.0)
# Requirement already satisfied: Pillow==8.1.0 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 26)) (8.1.0)
# Requirement already satisfied: protobuf==3.14.0 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 27)) (3.14.0)
# Requirement already satisfied: pyasn1==0.4.8 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 28)) (0.4.8)
# Requirement already satisfied: pyasn1-modules==0.2.8 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 29)) (0.2.8)
# Requirement already satisfied: pyparsing==2.4.7 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 30)) (2.4.7)
# Requirement already satisfied: python-dateutil==2.8.1 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 31)) (2.8.1)
# Requirement already satisfied: PyYAML==5.4.1 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 32)) (5.4.1)
# Requirement already satisfied: requests==2.25.1 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 33)) (2.25.1)
# Requirement already satisfied: requests-oauthlib==1.3.0 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 34)) (1.3.0)
# Requirement already satisfied: rsa==4.7.1 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 35)) (4.7.1)
# Requirement already satisfied: scikit-learn==0.24.1 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 36)) (0.24.1)
# Requirement already satisfied: scipy==1.6.0 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 37)) (1.6.0)
# Requirement already satisfied: six==1.15.0 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 38)) (1.15.0)
# Requirement already satisfied: tensorboard==2.4.1 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 39)) (2.4.1)
# Requirement already satisfied: tensorboard-plugin-wit==1.8.0 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 40)) (1.8.0)
# Requirement already satisfied: tensorflow==2.4.1 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 41)) (2.4.1)
# Requirement already satisfied: tensorflow-estimator==2.4.0 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 42)) (2.4.0)
# Requirement already satisfied: termcolor==1.1.0 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 43)) (1.1.0)
# Requirement already satisfied: threadpoolctl==2.1.0 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 44)) (2.1.0)
# Requirement already satisfied: typing-extensions==3.7.4.3 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 45)) (3.7.4.3)
# Requirement already satisfied: urllib3==1.26.3 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 46)) (1.26.3)
# Requirement already satisfied: Werkzeug==1.0.1 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 47)) (1.0.1)
# Requirement already satisfied: wrapt==1.12.1 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 48)) (1.12.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/app-root/lib/python3.8/site-packages (from astunparse==1.6.3->-r requirements.txt (line 2)) (0.37.0)
# Requirement already satisfied: setuptools>=40.3.0 in /opt/app-root/lib/python3.8/site-packages (from google-auth==1.27.0->-r requirements.txt (line 9)) (58.2.0)
# WARNING: You are using pip version 21.2.4; however, version 21.3 is available.
# You should consider upgrading via the '/opt/app-root/bin/python3.8 -m pip install --upgrade pip' command.
# /opt/app-root/src/tiny_results_v0.5/closed/reference/code/training/image_classification
# .
# ./y_labels.csv
# ./train.py
# ./eval_functions_eembc.py
# ./.gitignore
# ./calibration_samples.txt
# ./trained_models
# ./trained_models/trainedResnet.h5
# ./trained_models/train_acc_20201218.png
# ./trained_models/pretrainedResnet_quant.tflite
# ./trained_models/pretrainedResnet.h5
# ./trained_models/train_loss_20201218.png
# ./trained_models/pretrainedResnet.md5
# ./trained_models/pretrainedResnet_quant.md5
# ./trained_models/README.md
# ./trained_models/pretrainedResnet.tflite
# ./prepare_training_env.sh
# ./tflite_test.py
# ./.ipynb_checkpoints
# ./.ipynb_checkpoints/Untitled-checkpoint.ipynb
# ./.ipynb_checkpoints/train-checkpoint.py
# ./Untitled.ipynb
# ./convert_to_tflite.sh
# ./cifar-10-python.tar.gz.2
# ./download_cifar10_train_resnet.sh
# ./train_loss_acc.png
# ./cifar-10-batches-py
# ./cifar-10-batches-py/data_batch_2
# ./cifar-10-batches-py/data_batch_3
# ./cifar-10-batches-py/data_batch_1
# ./cifar-10-batches-py/data_batch_5
# ./cifar-10-batches-py/data_batch_4
# ./cifar-10-batches-py/batches.meta
# ./cifar-10-batches-py/test_batch
# ./cifar-10-batches-py/readme.html
# ./perf_samples
# ./perf_samples/bird_s_001740.bin
# ./perf_samples/toy_spaniel_s_000285.bin
# ./perf_samples/canal_boat_s_000032.bin
# ./perf_samples/attack_aircraft_s_000368.bin
# ./perf_samples/ostrich_s_001177.bin
# ./perf_samples/cargo_vessel_s_001797.bin
# ./perf_samples/twinjet_s_000970.bin
# ./perf_samples/hospital_ship_s_001788.bin
# ./perf_samples/felis_catus_s_001124.bin
# ./perf_samples/pekingese_s_001399.bin
# ./perf_samples/attack_aircraft_s_001547.bin
# ./perf_samples/domestic_cat_s_000516.bin
# ./perf_samples/mongrel_s_001240.bin
# ./perf_samples/prunella_modularis_s_000006.bin
# ./perf_samples/tabby_cat_s_000472.bin
# ./perf_samples/puppy_s_000035.bin
# ./perf_samples/automobile_s_001643.bin
# ./perf_samples/container_vessel_s_001096.bin
# ./perf_samples/tennessee_walker_s_000827.bin
# ./perf_samples/gelding_s_000407.bin
# ./perf_samples/tomcat_s_000773.bin
# ./perf_samples/dump_truck_s_001017.bin
# ./perf_samples/pekingese_s_001472.bin
# ./perf_samples/broodmare_s_001856.bin
# ./perf_samples/fire_truck_s_000771.bin
# ./perf_samples/puppy_s_000172.bin
# ./perf_samples/guard_boat_s_000208.bin
# ./perf_samples/automobile_s_002547.bin
# ./perf_samples/bird_s_000010.bin
# ./perf_samples/pekingese_s_001147.bin
# ./perf_samples/toy_s_002487.bin
# ./perf_samples/sambar_s_000481.bin
# ./perf_samples/barking_frog_s_000722.bin
# ./perf_samples/dog_s_002298.bin
# ./perf_samples/jumbo_jet_s_000272.bin
# ./perf_samples/felis_domesticus_s_000546.bin
# ./perf_samples/king_charles_spaniel_s_000293.bin
# ./perf_samples/garbage_truck_s_001400.bin
# ./perf_samples/tabby_s_000214.bin
# ./perf_samples/jumbo_jet_s_001151.bin
# ./perf_samples/pekingese_s_000021.bin
# ./perf_samples/sparrow_s_000281.bin
# ./perf_samples/car_s_000012.bin
# ./perf_samples/domestic_cat_s_000625.bin
# ./perf_samples/jumbojet_s_001264.bin
# ./perf_samples/reconnaissance_plane_s_000441.bin
# ./perf_samples/cat_s_000526.bin
# ./perf_samples/tipper_lorry_s_000475.bin
# ./perf_samples/ostrich_s_002173.bin
# ./perf_samples/passerine_s_000477.bin
# ./perf_samples/cargo_vessel_s_001909.bin
# ./perf_samples/motorcar_s_000579.bin
# ./perf_samples/aerial_ladder_truck_s_000162.bin
# ./perf_samples/dump_truck_s_001515.bin
# ./perf_samples/alces_alces_s_000279.bin
# ./perf_samples/mongrel_s_002015.bin
# ./perf_samples/fallow_deer_s_000481.bin
# ./perf_samples/biplane_s_000294.bin
# ./perf_samples/boat_s_002757.bin
# ./perf_samples/coupe_s_001679.bin
# ./perf_samples/passenger_ship_s_000578.bin
# ./perf_samples/station_wagon_s_002539.bin
# ./perf_samples/domestic_cat_s_000473.bin
# ./perf_samples/bird_s_000650.bin
# ./perf_samples/quarter_horse_s_001425.bin
# ./perf_samples/felis_catus_s_001276.bin
# ./perf_samples/true_frog_s_000424.bin
# ./perf_samples/fighter_s_000908.bin
# ./perf_samples/gelding_s_001328.bin
# ./perf_samples/hedge_sparrow_s_000171.bin
# ./perf_samples/roe_deer_s_000985.bin
# ./perf_samples/sika_s_001719.bin
# ./perf_samples/natterjack_s_000960.bin
# ./perf_samples/truck_s_002318.bin
# ./perf_samples/convertible_s_002373.bin
# ./perf_samples/chihuahua_s_000487.bin
# ./perf_samples/felis_catus_s_001318.bin
# ./perf_samples/puppy_s_000761.bin
# ./perf_samples/bomber_s_000026.bin
# ./perf_samples/wapiti_s_000930.bin
# ./perf_samples/fighter_aircraft_s_000288.bin
# ./perf_samples/lightship_s_000823.bin
# ./perf_samples/cervus_unicolor_s_000044.bin
# ./perf_samples/lipizzan_s_001314.bin
# ./perf_samples/canis_familiaris_s_000171.bin
# ./perf_samples/bufo_americanus_s_001113.bin
# ./perf_samples/dunnock_s_001076.bin
# ./perf_samples/biplane_s_000439.bin
# ./perf_samples/tomcat_s_000128.bin
# ./perf_samples/quarter_horse_s_000913.bin
# ./perf_samples/lippizan_s_001138.bin
# ./perf_samples/trailer_truck_s_000437.bin
# ./perf_samples/airliner_s_001545.bin
# ./perf_samples/passenger_ship_s_000580.bin
# ./perf_samples/truck_s_000145.bin
# ./perf_samples/hydrofoil_s_000784.bin
# ./perf_samples/cargo_ship_s_001066.bin
# ./perf_samples/powerboat_s_000032.bin
# ./perf_samples/odocoileus_hemionus_s_001104.bin
# ./perf_samples/bufo_viridis_s_001495.bin
# ./perf_samples/lark_s_001127.bin
# ./perf_samples/domestic_cat_s_001647.bin
# ./perf_samples/tabby_cat_s_002450.bin
# ./perf_samples/felis_catus_s_001382.bin
# ./perf_samples/domestic_cat_s_000825.bin
# ./perf_samples/appaloosa_s_000279.bin
# ./perf_samples/powerboat_s_002244.bin
# ./perf_samples/chihuahua_s_000591.bin
# ./perf_samples/wrecker_s_000932.bin
# ./perf_samples/car_s_001440.bin
# ./perf_samples/wagtail_s_001621.bin
# ./perf_samples/rhea_americana_s_000047.bin
# ./perf_samples/tabby_s_000171.bin
# ./perf_samples/delivery_truck_s_000162.bin
# ./perf_samples/toy_dog_s_000948.bin
# ./perf_samples/emu_s_002027.bin
# ./perf_samples/automobile_s_001333.bin
# ./perf_samples/car_s_001583.bin
# ./perf_samples/sparrow_s_001538.bin
# ./perf_samples/estate_car_s_001589.bin
# ./perf_samples/true_frog_s_000294.bin
# ./perf_samples/flying_bird_s_000001.bin
# ./perf_samples/tennessee_walking_horse_s_000510.bin
# ./perf_samples/dive_bomber_s_001256.bin
# ./perf_samples/convertible_s_000056.bin
# ./perf_samples/felis_catus_s_000316.bin
# ./perf_samples/felis_domesticus_s_000278.bin
# ./perf_samples/nandu_s_000703.bin
# ./perf_samples/passenger_ship_s_001774.bin
# ./perf_samples/freighter_s_002066.bin
# ./perf_samples/pilot_boat_s_001635.bin
# ./perf_samples/multiengine_airplane_s_000182.bin
# ./perf_samples/propeller_plane_s_001707.bin
# ./perf_samples/spring_frog_s_001471.bin
# ./perf_samples/green_frog_s_001451.bin
# ./perf_samples/chihuahua_s_001839.bin
# ./perf_samples/grass_frog_s_000060.bin
# ./perf_samples/finch_s_000646.bin
# ./perf_samples/bird_s_001257.bin
# ./perf_samples/mongrel_s_002045.bin
# ./perf_samples/gondola_s_000055.bin
# ./perf_samples/shooting_brake_s_001237.bin
# ./perf_samples/mackinaw_boat_s_000354.bin
# ./perf_samples/lorry_s_000844.bin
# ./perf_samples/quarter_horse_s_000682.bin
# ./perf_samples/felis_domesticus_s_000074.bin
# ./perf_samples/frog_s_002032.bin
# ./perf_samples/broodmare_s_000457.bin
# ./perf_samples/bufo_calamita_s_000843.bin
# ./perf_samples/wapiti_s_000565.bin
# ./perf_samples/domestic_cat_s_001722.bin
# ./perf_samples/honey_eater_s_000628.bin
# ./perf_samples/pekingese_s_001307.bin
# ./perf_samples/coupe_s_000007.bin
# ./perf_samples/jetliner_s_001590.bin
# ./perf_samples/motorcar_s_001346.bin
# ./perf_samples/tabby_cat_s_000196.bin
# ./perf_samples/tabby_s_001060.bin
# ./perf_samples/lippizaner_s_000613.bin
# ./perf_samples/plantation_walking_horse_s_000189.bin
# ./perf_samples/airbus_s_002266.bin
# ./perf_samples/stealth_fighter_s_000873.bin
# ./perf_samples/spadefoot_s_000812.bin
# ./perf_samples/apteryx_s_000295.bin
# ./perf_samples/ship_s_000352.bin
# ./perf_samples/sparrow_s_002280.bin
# ./perf_samples/racing_boat_s_000124.bin
# ./perf_samples/tabby_cat_s_002684.bin
# ./perf_samples/tipper_s_000338.bin
# ./perf_samples/lipizzan_s_001200.bin
# ./perf_samples/bufo_s_000324.bin
# ./perf_samples/pilot_boat_s_001085.bin
# ./perf_samples/auto_s_000495.bin
# ./perf_samples/spadefoot_s_000154.bin
# ./perf_samples/dama_dama_s_000412.bin
# ./perf_samples/stealth_bomber_s_000627.bin
# ./perf_samples/capreolus_capreolus_s_000382.bin
# ./perf_samples/accentor_s_000166.bin
# ./perf_samples/tipper_truck_s_000325.bin
# ./perf_samples/estate_car_s_000684.bin
# ./perf_samples/blenheim_spaniel_s_000781.bin
# ./perf_samples/cervus_elaphus_s_001261.bin
# ./perf_samples/rangifer_caribou_s_000065.bin
# ./perf_samples/dump_truck_s_002118.bin
# ./perf_samples/bird_s_001330.bin
# ./perf_samples/cargo_ship_s_000882.bin
# ./perf_samples/trucking_rig_s_000980.bin
# ./perf_samples/tomcat_s_001045.bin
# ./perf_samples/containership_s_000689.bin
# ./perf_samples/toy_dog_s_000794.bin
# ./perf_samples/cabin_cruiser_s_000748.bin
# ./perf_samples/elk_s_001728.bin
# ./perf_samples/pipit_s_001095.bin
# ./perf_samples/jumbojet_s_000222.bin
# ./perf_samples/cabin_cruiser_s_001162.bin
# ./perf_samples/lipizzan_s_001437.bin
# ./perf_samples/wagtail_s_002013.bin
# ./perf_samples/walking_horse_s_002036.bin
# ./perf_samples/struthio_camelus_s_001293.bin
# ./perf_samples/struthio_camelus_s_000751.bin
# ./keras_model.py
# ./README.md
# ./cifar-10-python.tar.gz.1
# ./__pycache__
# ./__pycache__/keras_model.cpython-38.pyc
# ./__pycache__/train.cpython-38.pyc
# ./model_converter.py
# ./requirements.txt
# ./perf_samples_idxs.npy
# ./cifar-10-python.tar.gz
# ./perf_samples_loader.py
# ./calibration_samples_idxs.npy
# ./test.py
# 2021-10-12 03:13:51.828398: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-10-12 03:13:54.725389: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Train data:  (50000, 32, 32, 3)
# Train filenames:  (50000,)
# Train labels:  (50000, 10)
# Test data:  (10000, 32, 32, 3)
# Test filenames:  (10000,)
# Test labels:  (10000, 10)
# Label names:  (10,)
# Figure(640x480)
# 2021-10-12 03:13:56.942976: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-10-12 03:13:56.943316: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2021-10-12 03:13:56.943337: W tensorflow/stream_executor/cuda/cuda_driver.cc:326] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-10-12 03:13:56.943477: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (jupyterhub-nb-admin-2ddiane): /proc/driver/nvidia/version does not exist
# 2021-10-12 03:13:56.943655: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-10-12 03:13:56.946311: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 32, 32, 16)   448         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 32, 32, 16)   64          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 32, 32, 16)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 16)   2320        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 16)   64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 16)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 16)   2320        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 16)   64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 32, 32, 16)   0           activation[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 16)   0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 16, 16, 32)   4640        activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 16, 16, 32)   128         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 16, 16, 32)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 16, 16, 32)   9248        activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 16, 16, 32)   544         activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 16, 16, 32)   128         conv2d_4[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 16, 16, 32)   0           conv2d_5[0][0]
#                                                                  batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 16, 16, 32)   0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 8, 8, 64)     18496       activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 8, 8, 64)     256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 8, 8, 64)     0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 8, 8, 64)     36928       activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 8, 8, 64)     2112        activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 8, 8, 64)     256         conv2d_7[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 8, 8, 64)     0           conv2d_8[0][0]
#                                                                  batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 8, 8, 64)     0           add_2[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 1, 1, 64)     0           activation_6[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 64)           0           average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 10)           650         flatten[0][0]
# ==================================================================================================
# Total params: 78,666
# Trainable params: 78,186
# Non-trainable params: 480
# __________________________________________________________________________________________________
# 2021-10-12 03:13:57.633696: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2021-10-12 03:13:57.645393: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2499995000 Hz
# Epoch 1/5
# Learning rate = 0.001000
# 1562/1562 [==============================] - 256s 163ms/step - loss: 1.7776 - accuracy: 0.3774
# Epoch 2/5
# Learning rate = 0.000990
# 1562/1562 [==============================] - 269s 172ms/step - loss: 1.2804 - accuracy: 0.5660
# Epoch 3/5
# Learning rate = 0.000980
# 1562/1562 [==============================] - 278s 178ms/step - loss: 1.1371 - accuracy: 0.6247
# Epoch 4/5
# Learning rate = 0.000970
# 1562/1562 [==============================] - 274s 175ms/step - loss: 1.0562 - accuracy: 0.6565
# Epoch 5/5
# Learning rate = 0.000961
# 1562/1562 [==============================] - 273s 174ms/step - loss: 0.9968 - accuracy: 0.6760

# %%
# %cd ./tiny_results_v0.5/closed/reference/code/training/image_classification/
'''
MLCommons
group: TinyMLPerf (https://github.com/mlcommons/tiny)

image classification on cifar10

train.py desc: loads data, trains and saves model, plots training metrics
'''

import numpy as np
import matplotlib.pyplot as plt
import pickle
import tensorflow as tf
from keras.callbacks import LearningRateScheduler
from keras.utils import to_categorical
import keras_model

import datetime

EPOCHS = 5
BS = 32

# get date ant time to save model
dt = datetime.datetime.today()
year = dt.year
month = dt.month
day = dt.day
hour = dt.hour
minute = dt.minute

"""
The CIFAR-10 dataset consists of 60000 32x32 colour images in 10 classes, with 6000 images per class. There are 50000 
training images and 10000 test images.
The dataset is divided into five training batches and one test batch, each with 10000 images. The test batch contains 
exactly 1000 randomly-selected images from each class. The training batches contain the remaining images in random 
order, but some training batches may contain more images from one class than another. Between them, the training 
batches contain exactly 5000 images from each class.
"""

#learning rate schedule
def lr_schedule(epoch):
    initial_learning_rate = 0.001
    decay_per_epoch = 0.99
    lrate = initial_learning_rate * (decay_per_epoch ** epoch)
    print('Learning rate = %f'%lrate)
    return lrate

lr_scheduler = LearningRateScheduler(lr_schedule)

#optimizer
optimizer = tf.keras.optimizers.Adam()

#define data generator
datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    #brightness_range=(0.9, 1.2),
    #contrast_range=(0.9, 1.2),
    validation_split=0.2
)

def unpickle(file):
    """load the cifar-10 data"""

    with open(file, 'rb') as fo:
        data = pickle.load(fo, encoding='bytes')
    return data


def load_cifar_10_data(data_dir, negatives=False):
    """
    Return train_data, train_filenames, train_labels, test_data, test_filenames, test_labels
    """

    # get the meta_data_dict
    # num_cases_per_batch: 1000
    # label_names: ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
    # num_vis: :3072

    meta_data_dict = unpickle(data_dir + "/batches.meta")
    cifar_label_names = meta_data_dict[b'label_names']
    cifar_label_names = np.array(cifar_label_names)

    # training data
    cifar_train_data = None
    cifar_train_filenames = []
    cifar_train_labels = []

    for i in range(1, 6):
        cifar_train_data_dict = unpickle(data_dir + "/data_batch_{}".format(i))
        if i == 1:
            cifar_train_data = cifar_train_data_dict[b'data']
        else:
            cifar_train_data = np.vstack((cifar_train_data, cifar_train_data_dict[b'data']))
        cifar_train_filenames += cifar_train_data_dict[b'filenames']
        cifar_train_labels += cifar_train_data_dict[b'labels']

    cifar_train_data = cifar_train_data.reshape((len(cifar_train_data), 3, 32, 32))
    if negatives:
        cifar_train_data = cifar_train_data.transpose(0, 2, 3, 1).astype(np.float32)
    else:
        cifar_train_data = np.rollaxis(cifar_train_data, 1, 4)
    cifar_train_filenames = np.array(cifar_train_filenames)
    cifar_train_labels = np.array(cifar_train_labels)

    cifar_test_data_dict = unpickle(data_dir + "/test_batch")
    cifar_test_data = cifar_test_data_dict[b'data']
    cifar_test_filenames = cifar_test_data_dict[b'filenames']
    cifar_test_labels = cifar_test_data_dict[b'labels']

    cifar_test_data = cifar_test_data.reshape((len(cifar_test_data), 3, 32, 32))
    if negatives:
        cifar_test_data = cifar_test_data.transpose(0, 2, 3, 1).astype(np.float32)
    else:
        cifar_test_data = np.rollaxis(cifar_test_data, 1, 4)
    cifar_test_filenames = np.array(cifar_test_filenames)
    cifar_test_labels = np.array(cifar_test_labels)

    return cifar_train_data, cifar_train_filenames, to_categorical(cifar_train_labels), \
        cifar_test_data, cifar_test_filenames, to_categorical(cifar_test_labels), cifar_label_names


if __name__ == "__main__":
    """load cifar10 data and trains model"""

    cifar_10_dir = 'cifar-10-batches-py'

    train_data, train_filenames, train_labels, test_data, test_filenames, test_labels, label_names = \
        load_cifar_10_data(cifar_10_dir)

    print("Train data: ", train_data.shape)
    print("Train filenames: ", train_filenames.shape)
    print("Train labels: ", train_labels.shape)
    print("Test data: ", test_data.shape)
    print("Test filenames: ", test_filenames.shape)
    print("Test labels: ", test_labels.shape)
    print("Label names: ", label_names.shape)

    # Don't forget that the label_names and filesnames are in binary and need conversion if used.

    # display some random training images in a 25x25 grid
    num_plot = 5
    f, ax = plt.subplots(num_plot, num_plot)
    for m in range(num_plot):
        for n in range(num_plot):
            idx = np.random.randint(0, train_data.shape[0])
            ax[m, n].imshow(train_data[idx])
            ax[m, n].get_xaxis().set_visible(False)
            ax[m, n].get_yaxis().set_visible(False)
    f.subplots_adjust(hspace=0.1)
    f.subplots_adjust(wspace=0)
    plt.show()

    new_model = keras_model.resnet_v1_eembc()
    new_model.summary()

    # compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied)
    datagen.fit(train_data)

    new_model.compile(
        optimizer=optimizer, loss='categorical_crossentropy', metrics='accuracy', loss_weights=None,
        weighted_metrics=None, run_eagerly=None )

    # fits the model on batches with real-time data augmentation:
    History = new_model.fit(datagen.flow(train_data, train_labels, batch_size=BS),
              steps_per_epoch=len(train_data) / BS, epochs=EPOCHS, callbacks=[lr_scheduler])

    plt.plot(np.array(range(EPOCHS)), History.history['loss'])
    plt.plot(np.array(range(EPOCHS)), History.history['accuracy'])
    plt.savefig('train_loss_acc.png')
    model_name = "trainedResnet.h5"
    new_model.save("trained_models/" + model_name)
# Out:
# /opt/app-root/src/tiny_results_v0.5/closed/reference/code/training/image_classification
# Train data:  (50000, 32, 32, 3)
# Train filenames:  (50000,)
# Train labels:  (50000, 10)
# Test data:  (10000, 32, 32, 3)
# Test filenames:  (10000,)
# Test labels:  (10000, 10)
# Label names:  (10,)
# 2021-10-12 03:51:54.132023: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-10-12 03:51:54.132199: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2021-10-12 03:51:54.132212: W tensorflow/stream_executor/cuda/cuda_driver.cc:326] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-10-12 03:51:54.132231: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (jupyterhub-nb-admin-2ddiane): /proc/driver/nvidia/version does not exist
# 2021-10-12 03:51:54.132445: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-10-12 03:51:54.134247: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 32, 32, 16)   448         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 32, 32, 16)   64          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 32, 32, 16)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 16)   2320        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 16)   64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 16)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 16)   2320        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 16)   64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 32, 32, 16)   0           activation[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 16)   0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 16, 16, 32)   4640        activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 16, 16, 32)   128         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 16, 16, 32)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 16, 16, 32)   9248        activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 16, 16, 32)   544         activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 16, 16, 32)   128         conv2d_4[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 16, 16, 32)   0           conv2d_5[0][0]
#                                                                  batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 16, 16, 32)   0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 8, 8, 64)     18496       activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 8, 8, 64)     256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 8, 8, 64)     0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 8, 8, 64)     36928       activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 8, 8, 64)     2112        activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 8, 8, 64)     256         conv2d_7[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 8, 8, 64)     0           conv2d_8[0][0]
#                                                                  batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 8, 8, 64)     0           add_2[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 1, 1, 64)     0           activation_6[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 64)           0           average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 10)           650         flatten[0][0]
# ==================================================================================================
# Total params: 78,666
# Trainable params: 78,186
# Non-trainable params: 480
# __________________________________________________________________________________________________
# 2021-10-12 03:51:54.921268: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2021-10-12 03:51:54.933392: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2499995000 Hz
# Epoch 1/5
# Learning rate = 0.001000
# 1562/1562 [==============================] - 255s 162ms/step - loss: 1.7572 - accuracy: 0.3821
# Epoch 2/5
# Learning rate = 0.000990
# 1562/1562 [==============================] - 265s 170ms/step - loss: 1.2588 - accuracy: 0.5779
# Epoch 3/5
# Learning rate = 0.000980
# 1562/1562 [==============================] - 274s 176ms/step - loss: 1.1297 - accuracy: 0.6283
# Epoch 4/5
# Learning rate = 0.000970
# 1562/1562 [==============================] - 276s 177ms/step - loss: 1.0528 - accuracy: 0.6563
# Epoch 5/5
# Learning rate = 0.000961
#  540/1562 [=========>....................] - ETA: 2:57 - loss: 0.9932 - accuracy: 0.6754
